# %%
import pandas as pd
import requests
import json
import time
#import prettytable

api_key="8074dc66f62543f89cb5feb0803ce64a"

#series id taken from https://www.bls.gov/help/hlpforma.htm#LA 
#choosing local area unemployment (LA), seasonalally adjusted (S), state data (area type code = A)

#                      1         2
#Series ID    12345678901234567890
#	Positions    Value            Field Name
#	1-2          LA               Prefix
#	3            U                Seasonal Adjustment Code
#	4-18         CN2810700000000  Area Code
#	19-20        03               Measure Code


#area_type_code	areatype_text
#A	Statewide
#B	Metropolitan areas
#C	Metropolitan divisions
#D	Micropolitan areas
#E	Combined areas
#F	Counties and equivalents
#G	Cities and towns above 25,000 population
#H	Cities and towns below 25,000 population in New England
#I	Parts of cities that cross county boundaries
#J	Multi-entity small labor market areas
#K	Intrastate parts of interstate areas
#L	Balance of state areas
#M	Census regions
#N	Census divisions


#Indicates the unit of measurement:

#06 Labor force,
#05 Employment,
#04 Unemployment, and
#03 Unemployment rate.


#retrieve local area unemployement area code data
file_area_codes = "./Resources/bls_local_area_code_data.txt"

df_area_codes = pd.read_csv(file_area_codes, sep='\t')

#create dataframe that pulls only state data (area_type_code = A, from BLS site)
df_state_area_codes=df_area_codes.loc[df_area_codes["area_type_code"]=="A"]

#create list to only pull 03(rate) and 06(labor pool)
measure_codes=["03","06"]

#initialize dataframe to hold 20 years of state unemployment data
df_state_unemployment_data = pd.DataFrame(columns=['footnotes', 'latest', 'period', 'periodName', 'value', 'year','area_code', 'measurecode'])

# %%
# cycle through measure codes

for ms_code in measure_codes:

# cycle through state data (includes PR & DC)

    for i in range(len(df_state_area_codes["area_code"])):  
        url = f"https://api.bls.gov/publicAPI/v2/timeseries/data/LAS{df_state_area_codes['area_code'][i]}{ms_code}?startyear=2000&endyear=2019&registrationkey={api_key}"
      
        ud=requests.get(url).json()
        df_state_data=pd.DataFrame(ud['Results']['series'][0]['data'])
        df_state_data["area_code"] = df_state_area_codes['area_code'][i]
        df_state_data["measurecode"] = ms_code
        
        df_state_unemployment_data=df_state_unemployment_data.append(df_state_data,ignore_index=True, sort=False)

# %%
df_state_unemployment_data
# Out:
#                                                footnotes latest period  \
# 0                [{'code': 'P', 'text': 'Preliminary.'}]   true    M05
# 1                                                   [{}]    NaN    M04
# 2                                                   [{}]    NaN    M03
# 3                                                   [{}]    NaN    M02
# 4                                                   [{}]    NaN    M01
# 5      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# 6      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M11
# 7      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M10
# 8      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M09
# 9      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M08
# 10     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M07
# 11     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M06
# 12     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M05
# 13     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M04
# 14     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M03
# 15     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M02
# 16     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M01
# 17     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# 18     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M11
# 19     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M10
# 20     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M09
# 21     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M08
# 22     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M07
# 23     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M06
# 24     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M05
# 25     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M04
# 26     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M03
# 27     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M02
# 28     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M01
# 29     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# ...                                                  ...    ...    ...
# 24202  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M06
# 24203  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M05
# 24204  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M04
# 24205  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M03
# 24206  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M02
# 24207  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M01
# 24208  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M12
# 24209  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M11
# 24210  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M10
# 24211  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M09
# 24212  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M08
# 24213  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M07
# 24214  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M06
# 24215  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M05
# 24216  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M04
# 24217  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M03
# 24218  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M02
# 24219  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M01
# 24220  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    
# 24231    January  1292719  2000  ST7200000000000          06
#
# [24232 rows x 8 columns]

# %%
df_state_unemployment_data["periodmonth"]=df_state_unemployment_data["period"].str[-2:]
df_state_unemployment_data["periodyearmonth"]=df_state_unemployment_data["year"]+df_state_unemployment_data["period"].str[-2:]
# Out:
#                                                footnotes latest period  \
# 0                [{'code': 'P', 'text': 'Preliminary.'}]   true    M05
# 1                                                   [{}]    NaN    M04
# 2                                                   [{}]    NaN    M03
# 3                                                   [{}]    NaN    M02
# 4                                                   [{}]    NaN    M01
# 5      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# 6      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M11
# 7      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M10
# 8      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M09
# 9      [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M08
# 10     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M07
# 11     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M06
# 12     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M05
# 13     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M04
# 14     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M03
# 15     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M02
# 16     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M01
# 17     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# 18     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M11
# 19     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M10
# 20     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M09
# 21     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M08
# 22     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M07
# 23     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M06
# 24     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M05
# 25     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M04
# 26     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M03
# 27     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M02
# 28     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M01
# 29     [{'code': 'B', 'text': 'Reflects revised popul...    NaN    M12
# ...                                                  ...    ...    ...
# 24202  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M06
# 24203  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M05
# 24204  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M04
# 24205  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M03
# 24206  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M02
# 24207  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M01
# 24208  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M12
# 24209  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M11
# 24210  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M10
# 24211  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M09
# 24212  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M08
# 24213  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M07
# 24214  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M06
# 24215  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M05
# 24216  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M04
# 24217  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M03
# 24218  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M02
# 24219  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M01
# 24220  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M12
# 24221  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M11
# 24222  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M10
# 24223  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M09
# 24224  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M08
# 24225  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M07
# 24226  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M06
# 24227  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M05
# 24228  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M04
# 24229  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M03
# 24230  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M02
# 24231  [{'code': 'Z', 'text': 'Reflects a new seasona...    NaN    M01
#
#       periodName    value  year        area_code measurecode periodmonth  \
# 0            May      3.7  2019  ST0100000000000          03          05
# 1          April      3.8  2019  ST0100000000000          03          04
# 2          March      3.7  2019  ST0100000000000          03          03
# 3       February      3.7  2019  ST0100000000000          03          02
# 4        January      3.8  2019  ST0100000000000          03          01
# 5       December      3.8  2018  ST0100000000000          03          12
# 6       November      3.8  2018  ST0100000000000          03          11
# 7        October      3.8  2018  ST0100000000000          03          10
# 8      September      3.8  2018  ST0100000000000          03          09
# 9         August      3.9  2018  ST0100000000000          03          08
# 10          July      4.0  2018  ST0100000000000          03          07
# 11          June      4.1  2018  ST0100000000000          03          06
# 12           May      4.1  2018  ST0100000000000          03          05
# 13         April      4.1  2018  ST0100000000000          03          04
# 14         March      4.0  2018  ST0100000000000          03          03
# 15      February      4.0  2018  ST0100000000000          03          02
# 16       January      3.9  2018  ST0100000000000          03          01
# 17      December      3.9  2017  ST0100000000000          03          12
# 18      November      3.9  2017  ST0100000000000          03          11
# 19       October      3.9  2017  ST0100000000000          03          10
# 20     September      4.0  2017  ST0100000000000          03          09
# 21        August      4.1  2017  ST0100000000000          03          08
# 22          July      4.2  2017  ST0100000000000          03          07
# 23          June      4.3  2017  ST0100000000000          03          06
# 24           May      4.5  2017  ST0100000000000          03          05
# 25         April      4.7  2017  ST0100000000000          03          04
# 26         March      5.0  2017  ST0100000000000          03          03
# 27      February      5.2  2017  ST0100000000000          03          02
# 28       January      5.5  2017  ST0100000000000          03          01
# 29      December      5.7  2016  ST0100000000000          03          12
# ...          ...      ...   ...              ...         ...         ...
# 24202       June  1322721  2002  ST7200000000000          06          06
# 24203        May  1321216  2002  ST7200000000000          06          05
# 24204      April  1321489  2002  ST7200000000000          06          04
# 24205      March  1324788  2002  ST7200000000000          06          03
# 24206   February  1332277  2002  ST7200000000000          06          02
# 24207    January  1295777  2002  ST7200000000000          06          01
# 24208   December  1293898  2001  ST7200000000000          06          12
# 24209   November  1290769  2001  ST7200000000000          06          11
# 24210    October  1285983  2001  ST7200000000000          06          10
# 24211  September  1280466  2001  ST7200000000000          06          09
# 24212     August  1274661  2001  ST7200000000000          06          08
# 24213       July  1269460  2001  ST7200000000000          06          07
# 24214       June  1265332  2001  ST7200000000000          06          06
# 24215        May  1263198  2001  ST7200000000000          06          05
# 24216      April  1263270  2001  ST7200000000000          06          04
# 24217      March  1264831  2001  ST7200000000000          06          03
# 24218   February  1267100  2001  ST7200000000000          06          02
# 24219    January  1269141  2001  ST7200000000000          06          01
# 24220   December  1271642  2000  ST7200000000000          06          12
# 24221   November  1274914  2000  ST7200000000000          06          11
# 24222    October  1279127  2000  ST7200000000000          06          10
# 24223  September  1284099  2000  ST7200000000000          06          09
# 24224     August  1289562  2000  ST7200000000000          06          08
# 24225       July  1294959  2000  ST7200000000000          06          07
# 24226       June  1299495  2000  ST7200000000000          06          06
# 24227        May  1302710  2000  ST7200000000000          06          05
# 24228      April  1303257  2000  ST7200000000000          06          04
# 24229      March  1301189  2000  ST7200000000000          06          03
# 24230   February  1297284  2000  ST7200000000000          06          02
# 24231    January  1292719  2000  ST7200000000000          06          01
#
#       periodyearmonth
# 0              201905
# 1              201904
# 2              201903
# 3              201902
# 4              201901
# 5              201812
# 6              201811
# 7              201810
# 8              201809
# 9              201808
# 10             201807
# 11             201806
# 12             201805
# 13             201804
# 14             201803
# 15             201802
# 16             201801
# 17             201712
# 18             201711
# 19             201710
# 20             201709
# 21             201708
# 22             201707
# 23             201706
# 24             201705
# 25             201704
# 26             201703
# 27             201702
# 28             201701
# 29             201612
# ...               ...
# 24202          200206
# 24203          200205
# 24204          200204
# 24205          200203
# 24206          200202
# 24207          200201
# 24208          200112
# 24209          200111
# 24210          200110
# 24211          200109
# 24212          200108
# 24213          200107
# 24214          200106
# 24215          200105
# 24216          200104
# 24217          200103
# 24218          200102
# 24219          200101
# 24220          200012
# 24221          200011
# 24222          200010
# 24223          200009
# 24224          200008
# 24225          200007
# 24226          200006
# 24227          200005
# 24228          200004
# 24229          200003
# 24230          200002
# 24231          200001
#
# [24232 rows x 10 columns]

# %%
#headers = {'Content-type': 'application/json'}
#data = json.dumps({"seriesid": state_series_03_1,"startyear":"2000", "endyear":"2019","registrationkey":"8074dc66f62543f89cb5feb0803ce64a"})
#state_unemp=requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers).json()

#q=requests.get('https://api.bls.gov/publicAPI/v2/timeseries/data/LAUCN281070000000003?startyear=2010&endyear=2014&area_type_code=A').json()
