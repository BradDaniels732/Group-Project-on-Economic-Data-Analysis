# %% [markdown]
# # Average Coders

# %% [markdown]
# ### Analyze and Visualize

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Main Dataframe that was produced in the earlier Jupyter Notebook
main_df_filename = "main_dataframe.csv"
main_df = pd.read_csv (main_df_filename)
print(f'The number of rows of data for the clean main dataframe is now {len(main_df.index)}')
main_df.head()
# Out:
# The number of rows of data for the clean main dataframe is now 336
#          date  st_interest  it_interest  lt_interest  cpi_index  pct_chg_cpi  \
# 0  1991-01-01         6.41         7.13         8.09      134.7         5.65
# 1  1991-02-01         6.12         6.87         7.85      134.8         5.31
# 2  1991-03-01         6.09         7.10         8.11      134.8         4.82
# 3  1991-04-01         5.83         6.95         8.04      135.1         4.81
# 4  1991-05-01         5.63         6.78         8.07      135.6         5.03
#
#    oil_price  pct_chg_oil_price  mtg_purchase  mtg_refi  pct_chg_mtg_purchase  \
# 0      25.23              10.37          25.0      11.0                -21.28
# 1      20.48              -7.37          25.0      11.0                -21.28
# 2      19.90              -2.40          25.0      11.0                -21.28
# 3      20.83              13.02          33.0      12.0                 -6.54
# 4      21.23              16.65          33.0      12.0                 -6.54
#
#    pct_cht_mtg_refi  employment  pct_chg_employment  avg_earnings  \
# 0             45.45      109056               -0.13         10.38
# 1             45.45      108735               -0.64         10.39
# 2             45.45      108576               -0.97         10.41
# 3            118.75      108367               -1.20         10.46
# 4            118.75      108251               -1.45         10.49
#
#    pct_chg_avg_earnings
# 0                  3.59
# 1                  3.18
# 2                  2.97
# 3                  3.36
# 4                  3.25

# %%
# Graph the percent change in employment and percent change in hourly earnings

# Set the size of the graph
fig, ax = plt.subplots(figsize=(12,12))
# plt.figure(figsize=(10,10))

# Give it a title, and labels for the axes
ax.set_title("Pct Chg in Employment and Hourly Earnings", size=16, weight="bold")
ax.set_xlabel("Months")
ax.set_ylabel("Year/Year Pct Chg")


# Add grid lines
# plt.grid()

# Create a list of marker types.  I couldn't figure out how to have "plt" show a default marker
# so I created this list of 15 marker types.
marker_type = ['o','v','^','<','>','s','p','*','h','H','1','2','3','4','+']

# Draw the lines
plt.plot(main_df["date"], main_df["pct_chg_employment"], color="Red", linewidth=1, label='%Chg Employment')
plt.plot(main_df["date"], main_df["pct_chg_avg_earnings"], color="Blue", linewidth=1, label='%Chg Earnings')

# Set the tick marks on the x-axis
tick_locations = np.arange(len(drugs))
rects = ax.bar (tick_locations, height=tumor_chgs, align="edge", color=bar_colors)

# Print the legend
plt.legend (loc="best")

# Save the Figure
plt.savefig ('Output/graph1.png')

# Show the Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ab4939102ee4> in <module>
#      21
#      22 # Set the tick marks on the x-axis
# ---> 23 start, end = get_xlim()
#      24 xaxis.set_ticks(np.arange(start, end, 12))
#      25
#
# NameError: name 'get_xlim' is not defined
